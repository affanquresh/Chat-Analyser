# %%
# !pip install pygit2==1.15.1
# %cd /content
# !git clone https://github.com/lllyasviel/Fooocus.git
# %cd /content/Fooocus
# !python entry_with_update.py --share --always-high-vram
# Out:
# Collecting pygit2==1.15.1
#   Downloading pygit2-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (3.3 kB)
# Requirement already satisfied: cffi>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from pygit2==1.15.1) (1.17.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.11/dist-packages (from cffi>=1.16.0->pygit2==1.15.1) (2.22)
# Downloading pygit2-1.15.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 50.6 MB/s eta 0:00:00
# Installing collected packages: pygit2
#   Attempting uninstall: pygit2
#     Found existing installation: pygit2 1.17.0
#     Uninstalling pygit2-1.17.0:
#       Successfully uninstalled pygit2-1.17.0
# Successfully installed pygit2-1.15.1
# /content
# Cloning into 'Fooocus'...
# remote: Enumerating objects: 6725, done.
# remote: Counting objects: 100% (1408/1408), done.
# remote: Compressing objects: 100% (148/148), done.
# remote: Total 6725 (delta 1351), reused 1260 (delta 1260), pack-reused 5317 (from 1)
# Receiving objects: 100% (6725/6725), 33.19 MiB | 17.14 MiB/s, done.
# Resolving deltas: 100% (3928/3928), done.
# /content/Fooocus
# Already up-to-date
# Update succeeded.
# [System ARGV] ['entry_with_update.py', '--share', '--always-high-vram']
# Python 3.11.12 (main, Apr  9 2025, 08:55:54) [GCC 11.4.0]
# Fooocus version: 2.5.5
# Error checking version for torchsde: No package metadata was found for torchsde
# Installing requirements
# [Cleanup] Attempting to delete content of temp dir /tmp/fooocus
# [Cleanup] Cleanup successful
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/xlvaeapp.pth" to /content/Fooocus/models/vae_approx/xlvaeapp.pth
#
# 100% 209k/209k [00:00<00:00, 11.5MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/vaeapp_sd15.pt" to /content/Fooocus/models/vae_approx/vaeapp_sd15.pth
#
# 100% 209k/209k [00:00<00:00, 10.6MB/s]
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/xl-to-v1_interposer-v4.0.safetensors" to /content/Fooocus/models/vae_approx/xl-to-v1_interposer-v4.0.safetensors
#
# 100% 5.40M/5.40M [00:00<00:00, 85.6MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_expansion.bin" to /content/Fooocus/models/prompt_expansion/fooocus_expansion/pytorch_model.bin
#
# 100% 335M/335M [00:01<00:00, 323MB/s]
# Downloading: "https://huggingface.co/lllyasviel/fav_models/resolve/main/fav/juggernautXL_v8Rundiffusion.safetensors" to /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
#
# 100% 6.62G/6.62G [00:40<00:00, 176MB/s]
# Downloading: "https://huggingface.co/stabilityai/stable-diffusion-xl-base-1.0/resolve/main/sd_xl_offset_example-lora_1.0.safetensors" to /content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors
#
# 100% 47.3M/47.3M [00:00<00:00, 248MB/s]
# Total VRAM 15095 MB, total RAM 12978 MB
# Set vram state to: HIGH_VRAM
# Always offload VRAM
# Device: cuda:0 Tesla T4 : native
# VAE dtype: torch.float32
# Using pytorch cross attention
# Refiner unloaded.
# IMPORTANT: You are using gradio version 3.41.2, however version 4.44.1 is available, please upgrade.
# --------
# Running on local URL:  http://127.0.0.1:7865
# Running on public URL: https://2dcc841854eb585194.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# model_type EPS
# UNet ADM Dimension 2816
# Using pytorch attention in VAE
# Working with z of shape (1, 4, 32, 32) = 4096 dimensions.
# Using pytorch attention in VAE
# extra {'cond_stage_model.clip_l.logit_scale', 'cond_stage_model.clip_l.text_projection'}
# left over keys: dict_keys(['cond_stage_model.clip_l.transformer.text_model.embeddings.position_ids'])
# loaded straight to GPU
# Requested to load SDXL
# Loading 1 new model
# Base model loaded: /content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors
# VAE loaded: None
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Fooocus V2 Expansion: Vocab with 642 words.
# Fooocus Expansion engine loaded for cuda:0, use_fp16 = True.
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# [Fooocus Model Management] Moving model(s) has taken 0.59 seconds
# 2025-04-24 14:32:14.570504: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1745505134.836210    2250 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1745505134.905976    2250 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-04-24 14:32:15.445940: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Started worker with PID 1191
# App started successful. Use the app with http://127.0.0.1:7865/ or 127.0.0.1:7865 or https://2dcc841854eb585194.gradio.live
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 3751469622743975177
# [Parameters] CFG = 4
# [Fooocus] Downloading upscale models ...
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_upscaler_s409985e5.bin" to /content/Fooocus/models/upscale_models/fooocus_upscaler_s409985e5.bin
#
# 100% 32.1M/32.1M [00:00<00:00, 245MB/s]
# [Fooocus] Downloading inpainter ...
# Downloading: "https://huggingface.co/lllyasviel/fooocus_inpaint/resolve/main/fooocus_inpaint_head.pth" to /content/Fooocus/models/inpaint/fooocus_inpaint_head.pth
#
# 100% 51.4k/51.4k [00:00<00:00, 9.23MB/s]
# Downloading: "https://huggingface.co/lllyasviel/fooocus_inpaint/resolve/main/inpaint_v26.fooocus.patch" to /content/Fooocus/models/inpaint/inpaint_v26.fooocus.patch
#
# 100% 1.23G/1.23G [00:04<00:00, 269MB/s]
# [Inpaint] Current inpaint model is /content/Fooocus/models/inpaint/inpaint_v26.fooocus.patch
# [Fooocus] Downloading control models ...
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/clip_vision_vit_h.safetensors" to /content/Fooocus/models/clip_vision/clip_vision_vit_h.safetensors
#
# 100% 1.84G/1.84G [00:11<00:00, 175MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/fooocus_ip_negative.safetensors" to /content/Fooocus/models/controlnet/fooocus_ip_negative.safetensors
#
# 100% 64.1k/64.1k [00:00<00:00, 4.73MB/s]
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/ip-adapter-plus-face_sdxl_vit-h.bin" to /content/Fooocus/models/controlnet/ip-adapter-plus-face_sdxl_vit-h.bin
#
# 100% 967M/967M [00:09<00:00, 107MB/s]
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 24
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Synthetic Refiner Activated
# Synthetic Refiner Activated
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1), ('/content/Fooocus/models/inpaint/inpaint_v26.fooocus.patch', 1.0)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Loaded LoRA [/content/Fooocus/models/inpaint/inpaint_v26.fooocus.patch] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 960 keys at weight 1.0.
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Requested to load SDXLClipModel
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 1.98 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.20 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# [Fooocus] VAE Inpaint encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.20 seconds
# [Fooocus] VAE encoding ...
# Final resolution is (1080, 1346), latent is (896, 1152).
# Downloading: "https://github.com/xinntao/facexlib/releases/download/v0.1.0/detection_Resnet50_Final.pth" to /content/Fooocus/models/controlnet/detection_Resnet50_Final.pth
#
# 100% 104M/104M [00:00<00:00, 336MB/s]
# Downloading: "https://github.com/xinntao/facexlib/releases/download/v0.2.2/parsing_parsenet.pth" to /content/Fooocus/models/controlnet/parsing_parsenet.pth
#
# 100% 81.4M/81.4M [00:00<00:00, 283MB/s]
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.57 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.45 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Parameters] Denoising Strength = 1
# [Parameters] Initial Latent shape: torch.Size([1, 4, 144, 112])
# Preparation time: 56.98 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.81 seconds
#  80% 24/30 [00:19<00:04,  1.24it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# [Fooocus Model Management] Moving model(s) has taken 0.50 seconds
# Refiner Swapped
# 100% 30/30 [00:25<00:00,  1.20it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 29.97 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.24 seconds
#  80% 24/30 [00:19<00:04,  1.23it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# [Fooocus Model Management] Moving model(s) has taken 0.47 seconds
# Refiner Swapped
# 100% 30/30 [00:25<00:00,  1.19it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 29.48 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 59.45 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 116.49 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.80 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 5534867881882233058
# [Parameters] CFG = 4
# [Fooocus] Downloading upscale models ...
# [Fooocus] Downloading inpainter ...
# [Inpaint] Current inpaint model is /content/Fooocus/models/inpaint/inpaint_v26.fooocus.patch
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 24
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Synthetic Refiner Activated
# Synthetic Refiner Activated
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.15 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# [Fooocus] VAE Inpaint encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.91 seconds
# [Fooocus] VAE encoding ...
# Final resolution is (1080, 1346), latent is (896, 1152).
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.56 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.49 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Parameters] Denoising Strength = 1
# [Parameters] Initial Latent shape: torch.Size([1, 4, 144, 112])
# Preparation time: 12.41 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.50 seconds
#  80% 24/30 [00:19<00:04,  1.23it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# [Fooocus Model Management] Moving model(s) has taken 0.48 seconds
# Refiner Swapped
# 100% 30/30 [00:25<00:00,  1.20it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.31 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 29.54 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.24 seconds
#  80% 24/30 [00:19<00:04,  1.21it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# [Fooocus Model Management] Moving model(s) has taken 0.48 seconds
# Refiner Swapped
# 100% 30/30 [00:25<00:00,  1.18it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 29.46 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 59.00 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 71.47 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.76 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 7081855682175354938
# [Parameters] CFG = 4
# [Fooocus] Downloading upscale models ...
# [Fooocus] Downloading inpainter ...
# [Inpaint] Current inpaint model is /content/Fooocus/models/inpaint/inpaint_v26.fooocus.patch
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 24
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Synthetic Refiner Activated
# Synthetic Refiner Activated
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# [Fooocus] VAE Inpaint encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.89 seconds
# [Fooocus] VAE encoding ...
# Final resolution is (1080, 1346), latent is (896, 1152).
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.56 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.49 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Parameters] Denoising Strength = 1
# [Parameters] Initial Latent shape: torch.Size([1, 4, 144, 112])
# Preparation time: 12.58 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.35 seconds
#  80% 24/30 [00:20<00:05,  1.15it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# [Fooocus Model Management] Moving model(s) has taken 0.48 seconds
# Refiner Swapped
# 100% 30/30 [00:26<00:00,  1.13it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.26 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 30.65 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.34 seconds
#  80% 24/30 [00:21<00:05,  1.15it/s]Requested to load SDXL
# Loading 1 new model
# unload clone 0
# [Fooocus Model Management] Moving model(s) has taken 0.47 seconds
# Refiner Swapped
# 100% 30/30 [00:26<00:00,  1.12it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 30.97 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 61.62 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 74.27 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.79 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 244178000052050140
# [Parameters] CFG = 4
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 30 - 15
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Requested to load SDXLClipModel
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 1.18 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# [Fooocus] VAE encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.80 seconds
# Final resolution is (1080, 1344).
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.57 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.47 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Parameters] Denoising Strength = 0.5
# [Parameters] Initial Latent shape: torch.Size([1, 4, 168, 135])
# Preparation time: 9.90 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2123857736587524
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.71 seconds
# 100% 30/30 [00:36<00:00,  1.22s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.35 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 41.20 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2123857736587524
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.61 seconds
# 100% 30/30 [00:37<00:00,  1.26s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 42.35 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 83.55 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 93.51 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.82 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 6195046224406856690
# [Parameters] CFG = 4
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# [Fooocus] VAE encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.86 seconds
# Final resolution is (1080, 1344).
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.56 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.51 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Parameters] Denoising Strength = 0.5
# [Parameters] Initial Latent shape: torch.Size([1, 4, 168, 135])
# Preparation time: 9.11 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2431749105453491
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.70 seconds
# 100% 60/60 [01:20<00:00,  1.35s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.26 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 85.61 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2431749105453491
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.64 seconds
# 100% 60/60 [01:20<00:00,  1.34s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 85.15 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 170.77 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 179.97 seconds
# [Fooocus Model Management] Moving model(s) has taken 1.00 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 2915563200113622503
# [Parameters] CFG = 4
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# [Fooocus] VAE encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.87 seconds
# Final resolution is (1080, 1080).
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.57 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.46 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Parameters] Denoising Strength = 0.5
# [Parameters] Initial Latent shape: torch.Size([1, 4, 135, 135])
# Preparation time: 8.61 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2431749105453491
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.70 seconds
# 100% 60/60 [01:06<00:00,  1.11s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.26 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 70.39 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2431749105453491
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.60 seconds
# 100% 60/60 [01:06<00:00,  1.10s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 69.92 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 140.31 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 148.97 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.87 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 5877555500050292994
# [Parameters] CFG = 4
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# [Fooocus] VAE encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.87 seconds
# Final resolution is (1080, 1080).
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.56 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.48 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Parameters] Denoising Strength = 0.5
# [Parameters] Initial Latent shape: torch.Size([1, 4, 135, 135])
# Preparation time: 8.97 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2431749105453491
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.65 seconds
# 100% 60/60 [01:00<00:00,  1.02s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 64.79 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2431749105453491
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.60 seconds
# 100% 60/60 [00:59<00:00,  1.00it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.26 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 63.73 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 128.53 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 137.55 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.90 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 5523401063274707484
# [Parameters] CFG = 4
# [Fooocus] Downloading upscale models ...
# [Inpaint] Parameterized inpaint is disabled.
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# Upscaling image with shape (435, 435, 3) ...
# [Fooocus] VAE Inpaint encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.95 seconds
# [Fooocus] VAE encoding ...
# Final resolution is (1080, 1080), latent is (1024, 1024).
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.55 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.46 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.26 seconds
# [Parameters] Denoising Strength = 0.5
# [Parameters] Initial Latent shape: torch.Size([1, 4, 128, 128])
# Preparation time: 13.83 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2431749105453491
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.65 seconds
# 100% 60/60 [00:49<00:00,  1.20it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 53.40 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2431749105453491
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.59 seconds
# 100% 60/60 [00:48<00:00,  1.23it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 52.57 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 105.97 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 119.89 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.88 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 8685452453723813579
# [Parameters] CFG = 4
# [Fooocus] Downloading upscale models ...
# [Inpaint] Parameterized inpaint is disabled.
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# Upscaling image with shape (435, 435, 3) ...
# [Fooocus] VAE Inpaint encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.91 seconds
# [Fooocus] VAE encoding ...
# Final resolution is (1080, 1080), latent is (1024, 1024).
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.56 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.47 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.26 seconds
# [Parameters] Denoising Strength = 0.5
# [Parameters] Initial Latent shape: torch.Size([1, 4, 128, 128])
# Preparation time: 13.18 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2431749105453491
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.65 seconds
# 100% 60/60 [00:52<00:00,  1.14it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.26 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 56.25 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2431749105453491
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.63 seconds
# 100% 60/60 [00:51<00:00,  1.16it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 55.20 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 111.46 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 124.68 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.85 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 2675867856504371689
# [Parameters] CFG = 4
# [Fooocus] Downloading upscale models ...
# [Inpaint] Parameterized inpaint is disabled.
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# Upscaling image with shape (435, 435, 3) ...
# [Fooocus] VAE Inpaint encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.89 seconds
# [Fooocus] VAE encoding ...
# Final resolution is (1080, 1080), latent is (1024, 1024).
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.56 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.46 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.26 seconds
# [Parameters] Denoising Strength = 0.5
# [Parameters] Initial Latent shape: torch.Size([1, 4, 128, 128])
# Preparation time: 13.29 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2431749105453491
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.67 seconds
# 100% 60/60 [00:52<00:00,  1.14it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 56.28 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2431749105453491
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.62 seconds
# 100% 60/60 [00:51<00:00,  1.16it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 55.21 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 111.49 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 124.84 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.87 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 5770763528999485071
# [Parameters] CFG = 4
# [Fooocus] Downloading upscale models ...
# [Inpaint] Parameterized inpaint is disabled.
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# Upscaling image with shape (435, 435, 3) ...
# [Fooocus] VAE Inpaint encoding ...
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.88 seconds
# [Fooocus] VAE encoding ...
# Final resolution is (1080, 1080), latent is (1024, 1024).
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.55 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.46 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.25 seconds
# [Parameters] Denoising Strength = 0.5
# [Parameters] Initial Latent shape: torch.Size([1, 4, 128, 128])
# Preparation time: 12.95 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2431749105453491
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.65 seconds
# 100% 60/60 [00:49<00:00,  1.21it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 53.35 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 1.2431749105453491
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.58 seconds
# 100% 60/60 [00:48<00:00,  1.23it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 52.56 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 105.90 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 118.93 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.90 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 4509133880503571768
# [Parameters] CFG = 4
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Image processing ...
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.12 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.47 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.26 seconds
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 7.48 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.65 seconds
# 100% 60/60 [00:54<00:00,  1.09it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.33 seconds
# [Fooocus] Saving image 1/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 58.48 seconds
# [Fooocus] Preparing task 2/2 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.59 seconds
# 100% 60/60 [00:54<00:00,  1.10it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.25 seconds
# [Fooocus] Saving image 2/2 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 58.09 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 116.56 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 124.13 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.93 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 1740765576603800177
# [Parameters] CFG = 4
# [Fooocus] Downloading control models ...
# Downloading: "https://huggingface.co/lllyasviel/misc/resolve/main/control-lora-canny-rank128.safetensors" to /content/Fooocus/models/controlnet/control-lora-canny-rank128.safetensors
#
# 100% 377M/377M [00:05<00:00, 76.0MB/s]
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.13 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Image processing ...
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.17 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.50 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.27 seconds
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (896, 1152)
# Preparation time: 12.89 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/3 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# ...
# Loading 2 new models
# Total time: 201.09 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.79 seconds
# Enter Lightning mode.
# [Fooocus] Downloading Lightning components ...
# Downloading: "https://huggingface.co/mashb1t/misc/resolve/main/sdxl_lightning_4step_lora.safetensors" to /content/Fooocus/models/loras/sdxl_lightning_4step_lora.safetensors
#
# 100% 376M/376M [00:11<00:00, 33.4MB/s]
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 1409024373575029813
# [Parameters] CFG = 1.0
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = euler - sgm_uniform
# [Parameters] Steps = 4 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1), ('sdxl_lightning_4step_lora.safetensors', 1.0)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Loaded LoRA [/content/Fooocus/models/loras/sdxl_lightning_4step_lora.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 1.0.
# Requested to load SDXLClipModel
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 1.18 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.11 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Image processing ...
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.09 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.44 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.25 seconds
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1216, 832)
# Preparation time: 17.70 seconds
# Using sgm_uniform scheduler.
# [Fooocus] Preparing task 1/3 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.02 seconds
# 100% 4/4 [00:02<00:00,  1.64it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.35 seconds
# [Fooocus] Saving image 1/3 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 7.13 seconds
# [Fooocus] Preparing task 2/3 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.97 seconds
# 100% 4/4 [00:02<00:00,  1.66it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 2/3 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 6.42 seconds
# [Fooocus] Preparing task 3/3 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.97 seconds
# 100% 4/4 [00:02<00:00,  1.60it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 3/3 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 6.55 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 20.10 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 37.84 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.80 seconds
# Enter Lightning mode.
# [Fooocus] Downloading Lightning components ...
# [Parameters] Adaptive CFG = 1.0
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 0.0
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.0 : 1.0 : 0.0
# [Parameters] Seed = 1917665080596773058
# [Parameters] CFG = 1.0
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = euler - sgm_uniform
# [Parameters] Steps = 4 - 4
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Image processing ...
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.08 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.43 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.24 seconds
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1216, 832)
# Preparation time: 5.29 seconds
# Using sgm_uniform scheduler.
# [Fooocus] Preparing task 1/3 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.01 seconds
# 100% 4/4 [00:02<00:00,  1.65it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 1/3 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 6.51 seconds
# [Fooocus] Preparing task 2/3 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.97 seconds
# 100% 4/4 [00:02<00:00,  1.61it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 2/3 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 6.53 seconds
# [Fooocus] Preparing task 3/3 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.6951494216918945, sigma_max = 14.614640235900879
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.98 seconds
# 100% 4/4 [00:02<00:00,  1.62it/s]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 3/3 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 6.53 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 19.57 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 24.89 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.83 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 3075083248498973905
# [Parameters] CFG = 4
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# Request to load LoRAs [('sd_xl_offset_example-lora_1.0.safetensors', 0.1)] for model [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors].
# Loaded LoRA [/content/Fooocus/models/loras/sd_xl_offset_example-lora_1.0.safetensors] for UNet [/content/Fooocus/models/checkpoints/juggernautXL_v8Rundiffusion.safetensors] with 788 keys at weight 0.1.
# Requested to load SDXLClipModel
# Loading 1 new model
# unload clone 1
# [Fooocus Model Management] Moving model(s) has taken 1.12 seconds
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.11 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Image processing ...
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.08 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.44 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.25 seconds
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1216, 832)
# Preparation time: 6.07 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/3 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.66 seconds
# 100% 60/60 [01:09<00:00,  1.17s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.30 seconds
# [Fooocus] Saving image 1/3 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 73.64 seconds
# [Fooocus] Preparing task 2/3 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.60 seconds
# 100% 60/60 [01:09<00:00,  1.16s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 2/3 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 73.12 seconds
# [Fooocus] Preparing task 3/3 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.58 seconds
# 100% 60/60 [01:09<00:00,  1.15s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 3/3 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 72.84 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 219.60 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 225.73 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.80 seconds
# [Parameters] Adaptive CFG = 7
# [Parameters] CLIP Skip = 2
# [Parameters] Sharpness = 2
# [Parameters] ControlNet Softness = 0.25
# [Parameters] ADM Scale = 1.5 : 0.8 : 0.3
# [Parameters] Seed = 8499444591927317981
# [Parameters] CFG = 4
# [Fooocus] Downloading control models ...
# [Fooocus] Loading control models ...
# [Parameters] Sampler = dpmpp_2m_sde_gpu - karras
# [Parameters] Steps = 60 - 30
# [Fooocus] Initializing ...
# [Fooocus] Loading models ...
# Refiner unloaded.
# [Fooocus] Processing prompts ...
# [Fooocus] Encoding positive #1 ...
# [Fooocus Model Management] Moving model(s) has taken 0.12 seconds
# [Fooocus] Encoding positive #2 ...
# [Fooocus] Encoding positive #3 ...
# [Fooocus] Encoding negative #1 ...
# [Fooocus] Encoding negative #2 ...
# [Fooocus] Encoding negative #3 ...
# [Fooocus] Image processing ...
# Detected 1 faces
# Requested to load CLIPVisionModelWithProjection
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 1.10 seconds
# Requested to load Resampler
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.45 seconds
# Requested to load To_KV
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.25 seconds
# [Parameters] Denoising Strength = 1.0
# [Parameters] Initial Latent shape: Image Space (1216, 832)
# Preparation time: 5.00 seconds
# Using karras scheduler.
# [Fooocus] Preparing task 1/3 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.70 seconds
# 100% 60/60 [01:09<00:00,  1.16s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.29 seconds
# [Fooocus] Saving image 1/3 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 73.73 seconds
# [Fooocus] Preparing task 2/3 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.61 seconds
# 100% 60/60 [01:09<00:00,  1.15s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 2/3 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 73.12 seconds
# [Fooocus] Preparing task 3/3 ...
# [Sampler] refiner_swap_method = joint
# [Sampler] sigma_min = 0.0291671771556139, sigma_max = 14.614643096923828
# Requested to load SDXL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.63 seconds
# 100% 60/60 [01:09<00:00,  1.15s/it]
# Requested to load AutoencoderKL
# Loading 1 new model
# [Fooocus Model Management] Moving model(s) has taken 0.28 seconds
# [Fooocus] Saving image 3/3 to system ...
# Image generated with private log at: /content/Fooocus/outputs/2025-04-24/log.html
# Generating and saving time: 73.02 seconds
# [Enhance] Skipping, preconditions aren't met
# Processing time (total): 219.87 seconds
# Requested to load SDXLClipModel
# Requested to load GPT2LMHeadModel
# Loading 2 new models
# Total time: 224.96 seconds
# [Fooocus Model Management] Moving model(s) has taken 0.87 seconds
# Keyboard interruption in main thread... closing server.
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.11/dist-packages/gradio/blocks.py", line 2199, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/content/Fooocus/entry_with_update.py", line 46, in <module>
#     from launch import *
#   File "/content/Fooocus/launch.py", line 152, in <module>
#     from webui import *
#   File "/content/Fooocus/webui.py", line 1120, in <module>
#     shared.gradio_root.launch(
#   File "/usr/local/lib/python3.11/dist-packages/gradio/blocks.py", line 2115, in launch
#     self.block_thread()
#   File "/usr/local/lib/python3.11/dist-packages/gradio/blocks.py", line 2203, in block_thread
#     self.server.close()
#   File "/usr/local/lib/python3.11/dist-packages/gradio/networking.py", line 49, in close
#     self.thread.join()
#   File "/usr/lib/python3.11/threading.py", line 1119, in join
#     self._wait_for_tstate_lock()
#   File "/usr/lib/python3.11/threading.py", line 1139, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt
# Killing tunnel 127.0.0.1:7865 <> https://2dcc841854eb585194.gradio.live
# ^C
